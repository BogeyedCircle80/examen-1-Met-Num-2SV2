# %%
import math
print("Este programa resuelve ecuaciones de segundo grado por 'la chicharronera' ")
a= float(input("ingrese el valor de a: "))
b= float(input("ingrese el valor de b: "))
c= float(input("ingrese el valor de c: "))

x= (b**2)-(4*a*c)
if x<0:
  print("Solución en numeros complejos")
  a= float(input("ingrese el valor de a: "))
  b= float(input("ingrese el valor de b: "))
  c= float(input("ingrese el valor de c: "))
  print("x1=", X1)
  print("x2=", X2)
  x1=(-b)/(2*a)
  print("x=", x1)
if x== 0:
    x1=(-b)/(2*a)
    print("x=", x1)
if x>0:
    X1= (-b+math.sqrt(x))/(2*a)
    X2= (-b-math.sqrt(x))/(2*a)
    print("x1=", X1)
    print("x2=", X2)
# Out:
# Este programa resuelve ecuaciones de segundo grado por 'la chicharronera'
# ingrese el valor de a: 4
# ingrese el valor de b: 8
# ingrese el valor de c: 4
# x= -1.0

# %%
print("sea: f(x)=e^(-x), -4<x<10")
def funcion (x):
  f= (2.718281)**(-x)
  return (f)

x=float(input("dame el valor de x"))
print("f(x) \t e^-x")
while x>-4 or x<10:
  x+=1
  ev= ((2.718281)**(-(x)))
  print("", x, "\t", ev)
  if ev<=0.0025:
    break
print()
# Out:
# f(x)=e^(-x)
# dame el valor de x-5
# f(x) 	 e^-x
#  -4.0 	 54.59808347299571
#  -3.0 	 20.085518558602185
#  -2.0 	 7.389051594961001
#  -1.0 	 2.718281
#  0.0 	 1.0
#  1.0 	 0.367879553291216
#  2.0 	 0.13533536572974464
#  3.0 	 0.0497871138891618
#  4.0 	 0.018315661217203738
#  5.0 	 0.0067379572668181615
#  6.0 	 0.0024787567094123678
